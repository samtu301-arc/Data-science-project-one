# %%
import pandas as pd

# %% [markdown]
# # Read a .csv from a URL with pandas

# %% [markdown]
# ### Target website:https://www.football-data.co.uk/data.php

# %%
#Reading 1 csv file from the website
df_premier21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E0.csv")

# %%
# showing dataframe
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal     2     0   H
# 1    E0  14/08/2021  12:30      Man United           Leeds     5     1   H
# 2    E0  14/08/2021  15:00         Burnley        Brighton     1     2   A
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace     3     0   H
# 4    E0  14/08/2021  15:00         Everton     Southampton     3     1   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United     1     0   H
# 376  E0  22/05/2022  16:00       Leicester     Southampton     4     1   H
# 377  E0  22/05/2022  16:00       Liverpool          Wolves     3     1   H
# 378  E0  22/05/2022  16:00        Man City     Aston Villa     3     2   H
# 379  E0  22/05/2022  16:00         Norwich       Tottenham     0     5   A
#
# ...

# %%
# rename columns
df_premier21.rename(columns = {"FTHG":"home_goals","FTAG":"away_goals"},inplace = True)

# %%
# show new dataframe
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  home_goals  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal           2
# 1    E0  14/08/2021  12:30      Man United           Leeds           5
# 2    E0  14/08/2021  15:00         Burnley        Brighton           1
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace           3
# 4    E0  14/08/2021  15:00         Everton     Southampton           3
# ..   ..         ...    ...             ...             ...         ...
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United           1
# 376  E0  22/05/2022  16:00       Leicester     Southampton           4
# 377  E0  22/05/2022  16:00       Liverpool          Wolves           3
# 378  E0  22/05/2022  16:00        Man City     Aston Villa           3
# 379  E0  22/05/2022  16:00         Norwich       Tottenham           0
#
#      away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# ...

# %% [markdown]
# # Read .csv from Multiple URLs with pandas

# %%
#--https://www.football-data.co.uk/mmz4281/2122/E0.csv
#--https://www.football-data.co.uk/mmz4281/2122/E1.csv

# %% [markdown]
# ### Link: Root + season + league

# %%
# Link stracture
"https://www.football-data.co.uk/mmz4281/" + "2122" + "/" + "E0" + ".csv"
# Out:
# 'https://www.football-data.co.uk/mmz4281/2122/E0.csv'

# %%
# create a root variable
root = "https://www.football-data.co.uk/mmz4281/"

# %% [markdown]
# # 2.1 Multiple Leagues

# %% [markdown]
# https://www.football-data.co.uk/mmz4281/2122/E0.csv
# https://www.football-data.co.uk/mmz4281/2122/E1.csv
# https://www.football-data.co.uk/mmz4281/2122/E2.csv
# https://www.football-data.co.uk/mmz4281/2122/E3.csv
# https://www.football-data.co.uk/mmz4281/2122/EC.csv

# %%
# creating list of leagues
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []
# looping througn leagues,read multiple csv and append it into a list
for league in leagues:
    df = pd.read_csv(root + '2122' + '/' + league +'.csv', encoding='unicode_escape')
    frames.append(df)

# %%
# length of dataframes
len(frames)
# Out:
# 5

# %%
# show 1st , 2nd and 3rd elementes
frames[1]
# Out:
#     Div        Date   Time          HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E1  06/08/2021  19:45       Bournemouth      West Brom     2     2   D
# 1    E1  07/08/2021  15:00         Blackburn        Swansea     2     1   H
# 2    E1  07/08/2021  15:00      Bristol City      Blackpool     1     1   D
# 3    E1  07/08/2021  15:00           Cardiff       Barnsley     1     1   D
# 4    E1  07/08/2021  15:00             Derby   Huddersfield     1     1   D
# ..   ..         ...    ...               ...            ...   ...   ...  ..
# 547  E1  07/05/2022  12:30           Preston  Middlesbrough     4     1   H
# 548  E1  07/05/2022  12:30  Sheffield United         Fulham     4     0   H
# 549  E1  07/05/2022  12:30             Stoke       Coventry     1     1   D
# 550  E1  07/05/2022  12:30           Swansea            QPR     0     1   A
# 551  E1  07/05/2022  12:30         West Brom       Barnsley     4     0   H
#
# ...

# %% [markdown]
# #          2.2 Multiple seasons

# %%
 for season in range(15, 21):
     print(str(season) + str(season+1))
# Out:
# 1516
# 1617
# 1718
# 1819
# 1920
# 2021

# %%
# creating list of leagues
leagues = ['E0', 'E2', 'E3',]
frames = []
# looping througn leagues,read multiple csv and append it into a list
for league in leagues:
    for season in range(15, 21):
        df = pd.read_csv(root + str(season) + str(season+1) + '/' + league +'.csv')
        df.insert(1, 'season', season)
        frames.append(df)

# %%
#total frames (6 seasons * 3 leagues)
len(frames)
# Out:
# 18

# %%
# show 1st and last elements( new season columns was created)
frames[0]
# Out:
#     Div  season        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0      15  08/08/2015  Bournemouth  Aston Villa     0     1   A     0
# 1    E0      15  08/08/2015      Chelsea      Swansea     2     2   D     2
# 2    E0      15  08/08/2015      Everton      Watford     2     2   D     0
# 3    E0      15  08/08/2015    Leicester   Sunderland     4     2   H     3
# 4    E0      15  08/08/2015   Man United    Tottenham     1     0   H     1
# ..   ..     ...         ...          ...          ...   ...   ...  ..   ...
# 375  E0      15  15/05/2016        Stoke     West Ham     2     1   H     0
# 376  E0      15  15/05/2016      Swansea     Man City     1     1   D     1
# 377  E0      15  15/05/2016      Watford   Sunderland     2     2   D     0
# 378  E0      15  15/05/2016    West Brom    Liverpool     1     1   D     1
# 379  E0      15  17/05/2016   Man United  Bournemouth     3     1   H     1
#
# ...

# %%
# show 1st and last elements( new season columns was created)
frames[17]
# Out:
#     Div  season        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG  \
# 0    E3      20  12/09/2020  15:00      Barrow       Stevenage     1     1
# 1    E3      20  12/09/2020  15:00      Bolton    Forest Green     0     1
# 2    E3      20  12/09/2020  15:00    Bradford      Colchester     0     0
# 3    E3      20  12/09/2020  15:00   Cambridge        Carlisle     3     0
# 4    E3      20  12/09/2020  15:00  Cheltenham       Morecambe     1     2
# ..   ..     ...         ...    ...         ...             ...   ...   ...
# 547  E3      20  08/05/2021  15:00   Port Vale       Mansfield     0     3
# 548  E3      20  08/05/2021  15:00  Scunthorpe       Stevenage     0     1
# 549  E3      20  08/05/2021  15:00    Southend  Newport County     1     1
# 550  E3      20  08/05/2021  15:00    Tranmere      Colchester     0     0
# 551  E3      20  08/05/2021  16:00     Salford   Leyton Orient     3     0
#
# ...

# %% [markdown]
# # Organize All Data in The Dictionary

# %%
# Create a dictionary with original name of league as a key
dict_countries = {'Spanish La Liga':'SP1',
                  'Spanish Segunda Division':'SP2',
                  'German Bundesliga':'D1',
                  'English Premier League':'E0',
                 'English League 1':'E1',
                 'English League 2':'E2'}

# %%
# get dictionary datas
dict_countries['English League 2']
# Out:
# 'E2'

# %%
for league in dict_countries:
    print(dict_countries[league])
# Out:
# SP1
# SP2
# D1
# E0
# E1
# E2

# %%
dict_historical_data = {}

# looping through key elements

# creating list of leagues
# leagues = ['E0', 'E2', 'E3',]
frames = []
# looping through key elements
for league in dict_countries:
    for season in range(15, 21):
        df = pd.read_csv(root + str(season) + str(season+1) + '/' + dict_countries[league] +'.csv')
        df.insert(1, 'season', season)
        frames.append(df)
    df_concat = pd.concat(frames)
    dict_historical_data[league] = df_concat

# %%
# show dataframe inside dict_historical_data
dict_historical_data['English Premier League']
# Out:
#      Div  season        Date          HomeTeam        AwayTeam  FTHG  FTAG  \
# 0    SP1      15    21/08/15            Malaga         Sevilla     0     0
# 1    SP1      15    22/08/15        Ath Madrid      Las Palmas     1     0
# 2    SP1      15    22/08/15           Espanol          Getafe     1     0
# 3    SP1      15    22/08/15         La Coruna        Sociedad     0     0
# 4    SP1      15    22/08/15         Vallecano        Valencia     0     0
# ..   ...     ...         ...               ...             ...   ...   ...
# 375   E0      20  23/05/2021         Liverpool  Crystal Palace     2     0
# 376   E0      20  23/05/2021          Man City         Everton     5     0
# 377   E0      20  23/05/2021  Sheffield United         Burnley     1     0
# 378   E0      20  23/05/2021          West Ham     Southampton     3     0
# 379   E0      20  23/05/2021            Wolves      Man United     1     2
#
# ...
